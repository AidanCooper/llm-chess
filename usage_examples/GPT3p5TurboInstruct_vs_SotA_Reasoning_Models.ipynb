# %% [markdown]
# ## gpt-3.5-turbo-instruct vs State of the Art Reasoning Models
#
# This notebook plays chess games between GPT 3.5 Turbo Instruct (released in 2023) and three state of the art reasoning models released in 2025 (Grok 4, OpenAI o3, and Gemini 2.5 Pro). Two games are played per reasoning model opponent — one with GPT 3.5 as white; one as black.
#
# Structured outputs were not enforced — the reasoning models were instructed to only return the selected move as the final response. An illegal move or malformatted response is considered an instant loss.
#
# ### Results
#
# GPT 3.5 Turbo Instruct wins all six games:
# ```text
# 1. GPT 3.5 vs Grok 4         : GPT 3.5 wins by checkmate
# 2. Grok 4 vs GPT 3.5         : Grok 4 loses by illegal move 'Re4' (GPT 3.5 has a 1240 centipawn advantage)
# 3. GPT 3.5 vs OpenAI o3      : OpenAI o3 loses by illegal move 'Qh7' (GPT 3.5 has mate in one)
# 4. OpenAI o3 vs GPT 3.5      : GPT 3.5 wins by checkmate
# 5. GPT 3.5 vs Gemini 2.5 Pro : GPT 3.5 wins by checkmate
# 6. Gemini 2.5 Pro vs GPT 3.5 : GPT 3.5 wins by checkmate
# ```
#
# ### Other observations:
# - Runtimes:
#   - Grok 4 is extremely slow, with game durations of 4h40m and 5h28m. I'm not sure if this is a rate limiting issue, slow token generation, excessive yapping, or something else.
#   - OpenAI o3's game durations were 1h39m and 2h44m.
#   - Gemini 2.5 Pro is extremely fast, with game durations of 28s and 26s. This implies it elected to do little-to-no reasoning, which could be a misinterpretation of the promp instructions: "RESPOND DIRECTLY WITH ONLY THE MOVE, no other text."

# %%
# %load_ext autoreload
# %autoreload 2

from datetime import datetime
from pathlib import Path

import chess
from tqdm.notebook import tqdm

from llm_chess.core.enums import APIResponseFormat
from llm_chess.core.game_manager import GameManager
from llm_chess.players.llm.openai import OpenAIPlayer
from llm_chess.players.llm.openai_instruct import GPT3p5TurboInstructPlayer
from llm_chess.players.llm.gemini import GeminiPlayer
from llm_chess.players.llm.grok import GrokPlayer
from llm_chess.prompts.pgn import PGNPromptConfig
from llm_chess.utils.write import write_board_to_pgn_file

# %%
PROJECT_ROOT = Path().cwd().parents[0]
LOG_DIR = PROJECT_ROOT / "game_logs" / "gpt_3p5_turbo_instruct_vs_sota_reasoning_models"

pgn_prompt_config = PGNPromptConfig(
    api_response_format=APIResponseFormat.TEXT,
    move_response_has_leading_space=False,
    prompt_prefix="Using SAN notation, respond with the next best chess move for the PGN game below. RESPOND DIRECTLY WITH ONLY THE MOVE, no other text.",
)

gpt = GPT3p5TurboInstructPlayer()

grok = GrokPlayer(
    name="Grok 4",
    model="grok-4-0709",
    prompt_config=pgn_prompt_config,
)

o3 = OpenAIPlayer(
    name="OpenAI o3",
    model="o3-2025-04-16",
    prompt_config=pgn_prompt_config,
    temperature=1.0,  # o3 only supports temperature=1
)

gemini = GeminiPlayer(
    name="Gemini Pro",
    model="gemini-2.5-pro",
    prompt_config=pgn_prompt_config,
)

# %%
games = [
    (gpt, grok),
    (grok, gpt),
    (gpt, o3),
    (o3, gpt),
    (gpt, gemini),
    (gemini, gpt),
]

# %%
for i, (white, black) in tqdm(enumerate(games, start=1), total=len(games), desc="Playing games..."):
    print(f"\nGame {i}/{len(games)}")

    # Play the game
    manager = GameManager()
    board = chess.Board()
    board, result = manager.play_game(
        white,
        black,
        board=board,
        displayer=None,
        print_move=True,
        sleep_time=0.2,
    )

    # Log the game
    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    file_name = f"{timestamp}_game_{i:05d}.pgn"
    write_board_to_pgn_file(
        board=board,
        write_dir=LOG_DIR,
        file_name=file_name,
        white_name=white.name,
        black_name=black.name,
        result=result,
    )

    if result == "1-0":
        print(f"  {white.name} won as white.")
    elif result == "0-1":
        print(f"  {black.name} won as black.")
    elif result == "1/2-1/2":
        print(f"  The game was a draw ({white.name} as white).")
    else:
        print(f"  Game result: {result} ({white.name} as white).")
# Out:
# Game 1/6
#     GPT-3.5 Turbo Instruct plays: e4
#     Grok 4                 plays: c5
#     GPT-3.5 Turbo Instruct plays: Nf3
#     Grok 4                 plays: d6
#     GPT-3.5 Turbo Instruct plays: d4
#     Grok 4                 plays: cxd4
#     GPT-3.5 Turbo Instruct plays: Nxd4
#     Grok 4                 plays: Nf6
#     GPT-3.5 Turbo Instruct plays: Nc3
#     Grok 4                 plays: a6
#     GPT-3.5 Turbo Instruct plays: Bg5
#     Grok 4                 plays: e6
#     GPT-3.5 Turbo Instruct plays: f4
#     Grok 4                 plays: Be7
#     GPT-3.5 Turbo Instruct plays: Qf3
#     Grok 4                 plays: Qc7
#     GPT-3.5 Turbo Instruct plays: O-O-O
#     Grok 4                 plays: Nbd7
#     GPT-3.5 Turbo Instruct plays: g4
#     Grok 4                 plays: b5
#     GPT-3.5 Turbo Instruct plays: Bxf6
#     Grok 4                 plays: Nxf6
#     GPT-3.5 Turbo Instruct plays: g5
#     Grok 4                 plays: Nd7
#     GPT-3.5 Turbo Instruct plays: f5
#     Grok 4                 plays: Nc5
#     GPT-3.5 Turbo Instruct plays: f6
#     Grok 4                 plays: gxf6
#     GPT-3.5 Turbo Instruct plays: gxf6
#     Grok 4                 plays: Bf8
#     GPT-3.5 Turbo Instruct plays: Rg1
#     Grok 4                 plays: h5
#     GPT-3.5 Turbo Instruct plays: Rg7
#     Grok 4                 plays: Bxg7
#     GPT-3.5 Turbo Instruct plays: fxg7
#     Grok 4                 plays: Rg8
#     GPT-3.5 Turbo Instruct plays: Qxh5
#     Grok 4                 plays: Rxg7
#     GPT-3.5 Turbo Instruct plays: Qh8+
#     Grok 4                 plays: Ke7
#     GPT-3.5 Turbo Instruct plays: Qxg7
#     Grok 4                 plays: Kd8
#     GPT-3.5 Turbo Instruct plays: Qf8+
#     Grok 4                 plays: Kd7
#     GPT-3.5 Turbo Instruct plays: Qxf7+
#     Grok 4                 plays: Kd8
#     GPT-3.5 Turbo Instruct plays: Qf8+
#     Grok 4                 plays: Kd7
#     GPT-3.5 Turbo Instruct plays: Bh3
#     Grok 4                 plays: Bb7
#     GPT-3.5 Turbo Instruct plays: Qf7+
#     Grok 4                 plays: Kd8
#     GPT-3.5 Turbo Instruct plays: Nxe6+
#     Grok 4                 plays: Nxe6
#     GPT-3.5 Turbo Instruct plays: Qxe6
#     Grok 4                 plays: Bc8
#     GPT-3.5 Turbo Instruct plays: Rxd6+
#     Grok 4                 plays: Qxd6
#     GPT-3.5 Turbo Instruct plays: Qxd6+
#     Grok 4                 plays: Ke8
#     GPT-3.5 Turbo Instruct plays: Nd5
#     Grok 4                 plays: Bxh3
#     GPT-3.5 Turbo Instruct plays: Qe7#
#   GPT-3.5 Turbo Instruct won as white.
#
# Game 2/6
#     Grok 4                 plays: e4
#     GPT-3.5 Turbo Instruct plays: e5
#     Grok 4                 plays: Nf3
#     GPT-3.5 Turbo Instruct plays: Nc6
#     Grok 4                 plays: Bb5
#     GPT-3.5 Turbo Instruct plays: a6
#     Grok 4                 plays: Ba4
#     GPT-3.5 Turbo Instruct plays: Nf6
#     Grok 4                 plays: O-O
#     GPT-3.5 Turbo Instruct plays: Be7
#     Grok 4                 plays: Re1
#     GPT-3.5 Turbo Instruct plays: b5
#     Grok 4                 plays: Bb3
#     GPT-3.5 Turbo Instruct plays: O-O
#     Grok 4                 plays: c3
#     GPT-3.5 Turbo Instruct plays: d5
#     Grok 4                 plays: exd5
#     GPT-3.5 Turbo Instruct plays: Nxd5
#     Grok 4                 plays: Nxe5
#     GPT-3.5 Turbo Instruct plays: Nxe5
#     Grok 4                 plays: Rxe5
#     GPT-3.5 Turbo Instruct plays: c6
#     Grok 4                 plays: d4
#     GPT-3.5 Turbo Instruct plays: Bd6
#     Grok 4                 plays: Re1
#     GPT-3.5 Turbo Instruct plays: Qh4
#     Grok 4                 plays: g3
#     GPT-3.5 Turbo Instruct plays: Qh3
#     Grok 4                 plays: Be3
#     GPT-3.5 Turbo Instruct plays: Bg4
#     Grok 4                 plays: Qd3
#     GPT-3.5 Turbo Instruct plays: Rae8
#     Grok 4                 plays: Nd2
#     GPT-3.5 Turbo Instruct plays: Re6
#     Grok 4                 plays: Qf1
#     GPT-3.5 Turbo Instruct plays: Qh5
#     Grok 4                 plays: f3
#     GPT-3.5 Turbo Instruct plays: Bh3
#     Grok 4                 plays: Qe2
#     GPT-3.5 Turbo Instruct plays: Rfe8
#     Grok 4                 plays: g4
#     GPT-3.5 Turbo Instruct plays: Qh4
#     Grok 4                 plays: Bxd5
#     GPT-3.5 Turbo Instruct plays: cxd5
#     Grok 4                 plays: Nf1
#     GPT-3.5 Turbo Instruct plays: Bxf1
#     Grok 4                 plays: Kxf1
#     GPT-3.5 Turbo Instruct plays: Rxe3
#     Grok 4                 plays: Qxe3
#     GPT-3.5 Turbo Instruct plays: Rxe3
#     Grok 4                 plays: Rxe3
#     GPT-3.5 Turbo Instruct plays: Qxh2
#     Grok 4                 plays: Re2
#     GPT-3.5 Turbo Instruct plays: Qh1+
#     Grok 4                 plays: Kf2
#     GPT-3.5 Turbo Instruct plays: Qxa1
#     Grok 4                 plays: Re8+
#     GPT-3.5 Turbo Instruct plays: Bf8
#     Grok 4                 plays: Re1
#     GPT-3.5 Turbo Instruct plays: Qxb2+
#     Grok 4                 plays: Re2
#     GPT-3.5 Turbo Instruct plays: Qxc3
#     Grok 4                 plays: Re3
#     GPT-3.5 Turbo Instruct plays: Qxd4
# Error: illegal san: 'Re4' in 5bk1/5ppp/p7/1p1p4/3q2P1/4RP2/P4K2/8 w - - 0 33
#   Game result: Illegal move by Grok 4 (Grok 4 as white).
#
# Game 3/6
#     GPT-3.5 Turbo Instruct plays: e4
#     OpenAI o3              plays: c5
#     GPT-3.5 Turbo Instruct plays: Nf3
#     OpenAI o3              plays: d6
#     GPT-3.5 Turbo Instruct plays: d4
#     OpenAI o3              plays: cxd4
#     GPT-3.5 Turbo Instruct plays: Nxd4
#     OpenAI o3              plays: Nf6
#     GPT-3.5 Turbo Instruct plays: Nc3
#     OpenAI o3              plays: a6
#     GPT-3.5 Turbo Instruct plays: Bg5
#     OpenAI o3              plays: e6
#     GPT-3.5 Turbo Instruct plays: f4
#     OpenAI o3              plays: Qb6
#     GPT-3.5 Turbo Instruct plays: Qd2
#     OpenAI o3              plays: Qxb2
#     GPT-3.5 Turbo Instruct plays: Rb1
#     OpenAI o3              plays: Qa3
#     GPT-3.5 Turbo Instruct plays: e5
#     OpenAI o3              plays: dxe5
#     GPT-3.5 Turbo Instruct plays: fxe5
#     OpenAI o3              plays: Nfd7
#     GPT-3.5 Turbo Instruct plays: Ne4
#     OpenAI o3              plays: h6
#     GPT-3.5 Turbo Instruct plays: Bh4
#     OpenAI o3              plays: Qxa2
#     GPT-3.5 Turbo Instruct plays: Rd1
#     OpenAI o3              plays: Qd5
#     GPT-3.5 Turbo Instruct plays: Qe3
#     OpenAI o3              plays: Qxe5
#     GPT-3.5 Turbo Instruct plays: Be2
#     OpenAI o3              plays: Bc5
#     GPT-3.5 Turbo Instruct plays: Bg3
#     OpenAI o3              plays: Qd5
#     GPT-3.5 Turbo Instruct plays: c4
#     OpenAI o3              plays: Bb4+
#     GPT-3.5 Turbo Instruct plays: Kf2
#     OpenAI o3              plays: Qf5+
#     GPT-3.5 Turbo Instruct plays: Nxf5
#     OpenAI o3              plays: Bc5
#     GPT-3.5 Turbo Instruct plays: Nxc5
#     OpenAI o3              plays: O-O
#     GPT-3.5 Turbo Instruct plays: Ne7+
#     OpenAI o3              plays: Kh8
#     GPT-3.5 Turbo Instruct plays: Nxc8
#     OpenAI o3              plays: Rxc8
#     GPT-3.5 Turbo Instruct plays: Nxd7
#     OpenAI o3              plays: Nxd7
#     GPT-3.5 Turbo Instruct plays: Rxd7
#     OpenAI o3              plays: Rd8
#     GPT-3.5 Turbo Instruct plays: Rxf7
#     OpenAI o3              plays: Rac8
#     GPT-3.5 Turbo Instruct plays: Be5
#     OpenAI o3              plays: Rf8
#     GPT-3.5 Turbo Instruct plays: Qxh6+
# Error: illegal san: 'Qh7' in 2r2r1k/1p3Rp1/p3p2Q/4B3/2P5/8/4BKPP/7R b - - 0 28
#   Game result: Illegal move by OpenAI o3 (GPT-3.5 Turbo Instruct as white).
#
# Game 4/6
#     OpenAI o3              plays: e4
#     GPT-3.5 Turbo Instruct plays: e5
#     OpenAI o3              plays: Nf3
#     GPT-3.5 Turbo Instruct plays: Nc6
#     OpenAI o3              plays: Bb5
#     GPT-3.5 Turbo Instruct plays: a6
#     OpenAI o3              plays: Ba4
#     GPT-3.5 Turbo Instruct plays: Nf6
#     OpenAI o3              plays: O-O
#     GPT-3.5 Turbo Instruct plays: Be7
#     OpenAI o3              plays: Re1
#     GPT-3.5 Turbo Instruct plays: b5
#     OpenAI o3              plays: Bb3
#     GPT-3.5 Turbo Instruct plays: O-O
#     OpenAI o3              plays: c3
#     GPT-3.5 Turbo Instruct plays: d5
#     OpenAI o3              plays: exd5
#     GPT-3.5 Turbo Instruct plays: Nxd5
#     OpenAI o3              plays: Nxe5
#     GPT-3.5 Turbo Instruct plays: Nxe5
#     OpenAI o3              plays: Rxe5
#     GPT-3.5 Turbo Instruct plays: c6
#     OpenAI o3              plays: d4
#     GPT-3.5 Turbo Instruct plays: Bd6
#     OpenAI o3              plays: Re1
#     GPT-3.5 Turbo Instruct plays: Qh4
#     OpenAI o3              plays: g3
#     GPT-3.5 Turbo Instruct plays: Qh3
#     OpenAI o3              plays: Re4
#     GPT-3.5 Turbo Instruct plays: g5
#     OpenAI o3              plays: Bxg5
#     GPT-3.5 Turbo Instruct plays: Qf5
#     OpenAI o3              plays: Re5
#     GPT-3.5 Turbo Instruct plays: Bxe5
#     OpenAI o3              plays: dxe5
#     GPT-3.5 Turbo Instruct plays: Qxg5
#     OpenAI o3              plays: Bxd5
#     GPT-3.5 Turbo Instruct plays: cxd5
#     OpenAI o3              plays: f4
#     GPT-3.5 Turbo Instruct plays: Qg4
#     OpenAI o3              plays: Qxd5
#     GPT-3.5 Turbo Instruct plays: Be6
#     OpenAI o3              plays: Qe4
#     GPT-3.5 Turbo Instruct plays: Qd1+
#     OpenAI o3              plays: Kf2
#     GPT-3.5 Turbo Instruct plays: Bd5
#     OpenAI o3              plays: Qe2
#     GPT-3.5 Turbo Instruct plays: Qh1
#     OpenAI o3              plays: Qg4+
#     GPT-3.5 Turbo Instruct plays: Kh8
#     OpenAI o3              plays: Qh3
#     GPT-3.5 Turbo Instruct plays: Qf3+
#     OpenAI o3              plays: Kg1
#     GPT-3.5 Turbo Instruct plays: Qe3+
#     OpenAI o3              plays: Kf1
#     GPT-3.5 Turbo Instruct plays: Bc4+
#     OpenAI o3              plays: Kg2
#     GPT-3.5 Turbo Instruct plays: Qe2+
#     OpenAI o3              plays: Kh1
#     GPT-3.5 Turbo Instruct plays: Bd5+
#     OpenAI o3              plays: Kg1
#     GPT-3.5 Turbo Instruct plays: Qe1+
#     OpenAI o3              plays: Qf1
#     GPT-3.5 Turbo Instruct plays: Qxf1+
#     OpenAI o3              plays: Kxf1
#     GPT-3.5 Turbo Instruct plays: f6
#     OpenAI o3              plays: exf6
#     GPT-3.5 Turbo Instruct plays: Rxf6
#     OpenAI o3              plays: a4
#     GPT-3.5 Turbo Instruct plays: Re8
#     OpenAI o3              plays: axb5
#     GPT-3.5 Turbo Instruct plays: axb5
#     OpenAI o3              plays: Kf2
#     GPT-3.5 Turbo Instruct plays: Rfe6
#     OpenAI o3              plays: Na3
#     GPT-3.5 Turbo Instruct plays: Re2+
#     OpenAI o3              plays: Kf1
#     GPT-3.5 Turbo Instruct plays: Rxh2
#     OpenAI o3              plays: Re1
#     GPT-3.5 Turbo Instruct plays: Rh1+
#     OpenAI o3              plays: Kf2
#     GPT-3.5 Turbo Instruct plays: Rexe1
#     OpenAI o3              plays: g4
#     GPT-3.5 Turbo Instruct plays: Rhf1+
#     OpenAI o3              plays: Kg3
#     GPT-3.5 Turbo Instruct plays: Re3+
#     OpenAI o3              plays: Kh4
#     GPT-3.5 Turbo Instruct plays: h6
#     OpenAI o3              plays: Kh5
#     GPT-3.5 Turbo Instruct plays: Kg7
#     OpenAI o3              plays: g5
#     GPT-3.5 Turbo Instruct plays: Rh3+
#     OpenAI o3              plays: Kg4
#     GPT-3.5 Turbo Instruct plays: Be6+
#     OpenAI o3              plays: f5
#     GPT-3.5 Turbo Instruct plays: Bxf5#
#   GPT-3.5 Turbo Instruct won as black.
#
# Game 5/6
#     GPT-3.5 Turbo Instruct plays: e4
#     Gemini Pro             plays: e5
#     GPT-3.5 Turbo Instruct plays: Nf3
#     Gemini Pro             plays: Bc5
#     GPT-3.5 Turbo Instruct plays: Nxe5
#     Gemini Pro             plays: Bxf2+
#     GPT-3.5 Turbo Instruct plays: Kxf2
#     Gemini Pro             plays: f6
#     GPT-3.5 Turbo Instruct plays: Qh5+
#     Gemini Pro             plays: g6
#     GPT-3.5 Turbo Instruct plays: Nxg6
#     Gemini Pro             plays: hxg6
#     GPT-3.5 Turbo Instruct plays: Qxh8
#     Gemini Pro             plays: g5
#     GPT-3.5 Turbo Instruct plays: Qxg8+
#     Gemini Pro             plays: Ke7
#     GPT-3.5 Turbo Instruct plays: Qg7+
#     Gemini Pro             plays: Kd6
#     GPT-3.5 Turbo Instruct plays: d4
#     Gemini Pro             plays: f5
#     GPT-3.5 Turbo Instruct plays: Bxg5
#     Gemini Pro             plays: Nc6
#     GPT-3.5 Turbo Instruct plays: Bxd8
#     Gemini Pro             plays: Rb8
#     GPT-3.5 Turbo Instruct plays: Qf6#
#   GPT-3.5 Turbo Instruct won as white.
#
# Game 6/6
#     Gemini Pro             plays: e4
#     GPT-3.5 Turbo Instruct plays: e5
#     Gemini Pro             plays: Nf3
#     GPT-3.5 Turbo Instruct plays: Nc6
#     Gemini Pro             plays: Be2
#     GPT-3.5 Turbo Instruct plays: Nf6
#     Gemini Pro             plays: d3
#     GPT-3.5 Turbo Instruct plays: d5
#     Gemini Pro             plays: exd5
#     GPT-3.5 Turbo Instruct plays: Nxd5
#     Gemini Pro             plays: O-O
#     GPT-3.5 Turbo Instruct plays: Be7
#     Gemini Pro             plays: g3
#     GPT-3.5 Turbo Instruct plays: O-O
#     Gemini Pro             plays: g4
#     GPT-3.5 Turbo Instruct plays: Bxg4
#     Gemini Pro             plays: Bd2
#     GPT-3.5 Turbo Instruct plays: Bh3
#     Gemini Pro             plays: Bc1
#     GPT-3.5 Turbo Instruct plays: Qd7
#     Gemini Pro             plays: Bd2
#     GPT-3.5 Turbo Instruct plays: Qg4+
#     Gemini Pro             plays: Kh1
#     GPT-3.5 Turbo Instruct plays: Qg2#
#   GPT-3.5 Turbo Instruct won as black.
